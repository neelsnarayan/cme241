# %%
# %load_ext autoreload
# %autoreload 2

#standard imports
import numpy as np
import pandas as pd
import numpy as np
import pandas as pd
import sys
sys.path.append("..")

#rl book imports
import rl
from rl.markov_decision_process import MarkovDecisionProcess
from rl.markov_process import State, MarkovProcess, NonTerminal, Terminal

from typing import (Callable, Dict, Generic, Iterator, Iterable, List,
                    Mapping, Optional, Sequence, Tuple, TypeVar, overload)

from rl.distribution import Categorical, Distribution, Constant, Choose
from rl.policy import Policy
from rl.monte_carlo import epsilon_greedy_policy, greedy_policy_from_qvf, glie_mc_control
from rl.function_approx import LinearFunctionApprox, AdamGradient
from rl.td import glie_sarsa


#custom imports 
import utils as u
import data as dat
import mdp_agent as ag
import baseline_policies as bp
import q_plots as qp
import backtest as btest
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Finite Horizon Trading MDP for mean reverting residuals.

# %% [markdown]
# The goal of this part is to see wether an RL agent can an optimal trading rule using a simple mean reverting residual process

# %%
mu=100
sigma = 30
train, test = dat.build_simulated_train_test(N=10,mu=mu,sigma=sigma)
u.plot_plotly_multiple(train)

# %% [markdown]
# Some algorithms we have are :
# - `glie_mc_control` (p. 352)
# - `glie_sarsa` (p. 358)
# -  `q_learning` but needs also `policy_from_q: PolicyFromQType`(p.365)
# - `q_learning_experience_replay`but needs also `policy_from_q: PolicyFromQType`(p.393)
# - `least_squares_policy_iteration` but takes in argument `initial_target_policy: DeterministicPolicy[S, A]` and `transitions: Iterable[TransitionStep[S, A]]`

# %% [markdown]
# #### Baseline trading policies

# %%
trader = ag.Trading(train,test)
threshold_policy = bp.ThresholdTradingPolicy(enter_long = mu-0.3*sigma, exit_long=mu-0.05*sigma, enter_short = mu+0.3*sigma, exit_short = mu+0.05*sigma)
bt = btest.Backtester(trader, threshold_policy)
bt.summary()

# %% [markdown]
# Train

# %%
mdp_trading = ag.Trading(train,test)

states = mdp_trading.generate_start_state("train")

approx_0  = mdp_trading.build_q_approx()

epsilon_as_func_of_episodes = lambda k: 1/k

gamma = 0.9

qvfs_mc = glie_mc_control(
    mdp_trading,
    states,
    approx_0,
    gamma,
    epsilon_as_func_of_episodes
)

# %% [markdown]
# Get q value

# %%
num_iter = 100000
final_qvf = None
for i,qvf in enumerate(qvfs_mc):
    if i%1000==0:
        print(i)
    if i>=num_iter:
        break
    final_qvf = qvf
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [57], line 3
#       1 num_iter = 100000
#       2 final_qvf = None
# ----> 3 for i,qvf in enumerate(qvfs_mc):
#       4     if i%1000==0:
#       5         print(i)
#
# File ~/Desktop/cme241/RL_Project/../rl/monte_carlo.py:139, in glie_mc_control(mdp, states, approx_0, γ, ε_as_func_of_episodes, episode_length_tolerance)
#     136 trace: Iterable[TransitionStep[S, A]] = \
#     137     mdp.simulate_actions(states, p)
#     138 num_episodes += 1
# --> 139 for step in returns(trace, γ, episode_length_tolerance):
#     140     q = q.update([((step.state, step.action), step.return_)])
#     141 p = epsilon_greedy_policy(q, mdp, ϵ_as_func_of_episodes(num_episodes))
#
# File ~/Desktop/cme241/RL_Project/../rl/returns.py:48, in returns(trace, γ, tolerance)
#      45 if max_steps is not None:
#      46     trace = itertools.islice(trace, max_steps * 2)
# ---> 48 *transitions, last_transition = list(trace)
#      50 return_steps = iterate.accumulate(
#      51     reversed(transitions),
#      52     func=lambda next, curr: curr.add_return(γ, next.return_),
#      53     initial=last_transition.add_return(γ, 0)
#      54 )
#      55 return_steps = reversed(list(return_steps))
#
# File ~/Desktop/cme241/RL_Project/../rl/markov_decision_process.py:99, in MarkovDecisionProcess.simulate_actions(self, start_states, policy)
#      96 action_distribution = policy.act(state)
#      98 action = action_distribution.sample()
# ---> 99 next_distribution = self.step(state, action)
#     101 next_state, reward = next_distribution.sample()
#     102 yield TransitionStep(state, action, next_state, reward)
#
# File ~/Desktop/cme241/RL_Project/mdp_agent.py:77, in Trading.step(self, state, action)
#      74 pos = state.state["position"] #is +1  -1 or 0
#      76 #Fetch next spot value and compute the return
# ---> 77 t, is_last = u.get_next(t_1, data)
#      78 S_t = data.loc[t][0]
#      79 r =  pos*(S_t - S_t_1)/S_t
#
# File ~/Desktop/cme241/RL_Project/utils.py:27, in get_next(date, data)
#      24 date = pd.to_datetime(date)
#      26 # Ensure the DataFrame's index is in datetime format
# ---> 27 data.index = pd.to_datetime(data.index)
#      29 # Find the next index
#      30 next_indices = data.index[data.index > date]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1073, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1071     result = _assemble_from_unit_mappings(arg, errors, tz)
#    1072 elif isinstance(arg, Index):
# -> 1073     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1074     if not cache_array.empty:
#    1075         result = _convert_and_box_cache(arg, cache_array, name=arg.name)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:224, in _maybe_cache(arg, format, cache, convert_listlike)
#     220 cache_array = Series(dtype=object)
#     222 if cache:
#     223     # Perform a quicker unique check
# --> 224     if not should_cache(arg):
#     225         return cache_array
#     227     unique_dates = unique(arg)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:186, in should_cache(arg, unique_share, check_count)
#     182 assert 0 < unique_share < 1, "unique_share must be in next bounds: (0; 1)"
#     184 try:
#     185     # We can't cache if the items are not hashable.
# --> 186     unique_elements = set(islice(arg, check_count))
#     187 except TypeError:
#     188     return False
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py:590, in DatetimeArray.__iter__(self)
#     588 start_i = i * chunksize
#     589 end_i = min((i + 1) * chunksize, length)
# --> 590 converted = ints_to_pydatetime(
#     591     data[start_i:end_i],
#     592     tz=self.tz,
#     593     freq=self.freq,
#     594     box="timestamp",
#     595     reso=self._reso,
#     596 )
#     597 yield from converted
#
# KeyboardInterrupt:

# %% [markdown]
# Visualize Q

# %%
qanalysis = qp.QAnalyzer(test,final_qvf)
qanalysis.plot_snapshot()

# %% [markdown]
# Backtest

# %%
trading_policy  = greedy_policy_from_qvf(final_qvf, lambda x : [-1,0,1])
bt = btest.Backtester(mdp_trading,trading_policy)
bt.summary()
