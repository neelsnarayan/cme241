# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
res = np.load("AvPCA_OOSresiduals_10_factors_1998_initialOOSYear_60_rollingWindow_252_covWindow_0.01_Cap.npy")

# %%
plt.plot(res[70,:].cumsum())
